# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\bhara\Downloads\CSV\ML\weather.csv")
df
# Out:
#           Date       City  Temperature_C  Rainfall_mm  Humidity  \
# 0   2024-01-05  Hyderabad             26            0        45
# 1   2024-02-10  Hyderabad             28            2        48
# 2   2024-03-15  Hyderabad             32            5        42
# 3   2024-04-20  Hyderabad             36           10        38
# 4   2024-05-25  Hyderabad             39           20        35
# 5   2024-06-10  Hyderabad             34          120        70
# 6   2024-07-15  Hyderabad             30          180        75
# 7   2024-08-18  Hyderabad             29          150        78
# 8   2024-09-22  Hyderabad             31           90        65
# 9   2024-10-10  Hyderabad             29           40        55
# 10  2024-11-12  Hyderabad             27            5        50
# 11  2024-12-20  Hyderabad             25            0        48
#
#     WindSpeed_kmph
# 0                8
# 1                9
# 2               10
# 3               12
# 4               14
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
plt.figure()
plt.plot(df['Date'], df['Temperature_C'], marker='o')
plt.title("Temperature Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
seasonal_temp = df.groupby('Month')['Temperature_C'].mean()

seasonal_temp.plot(kind='bar')
plt.title("Average Monthly Temperature")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
plt.figure()
sns.barplot(x='Month', y='Rainfall_mm', data=df)
plt.title("Monthly Rainfall Distribution")
plt.xlabel("Month")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
df.describe()
# Out:
#                       Date  Temperature_C  Rainfall_mm   Humidity  \
# count                   12       12.00000    12.000000  12.000000
# mean   2024-06-30 12:00:00       30.50000    51.833333  54.083333
# min    2024-01-05 00:00:00       25.00000     0.000000  35.000000
# 25%    2024-04-11 00:00:00       27.75000     4.250000  44.250000
# 50%    2024-06-27 12:00:00       29.50000    15.000000  49.000000
# 75%    2024-09-26 12:00:00       32.50000    97.500000  66.250000
# max    2024-12-20 00:00:00       39.00000   180.000000  78.000000
# std                    NaN        4.16697    65.583858  14.538090
#
#        WindSpeed_kmph      Month    Year
# count       12.000000  12.000000    12.0
# mean        13.000000   6.500000  2024.0
# min          8.000000   1.000000  2024.0
# 25%          9.750000   3.750000  2024.0
# 50%         12.000000   6.500000  2024.0
# 75%         15.750000   9.250000  2024.0
# max         20.000000  12.000000  2024.0
# ...
