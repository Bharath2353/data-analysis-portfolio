# %%
#IMPORT LIBRARIES
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\bhara\Downloads\CSV\ML\student_performance.csv")

# %%
#check whether the dataset is loded corectly or nor by displaying first 5 rows 
df.head()
# Out:
#    Student_ID   Name      Subject  Marks  Attendance
# 0         101  Aarav  Mathematics     78          92
# 1         102   Diya  Mathematics     65          85
# 2         103  Rahul  Mathematics     34          60
# 3         104  Sneha  Mathematics     88          95
# 4         105  Kiran  Mathematics     42          70

# %%
#size of dataset
df.shape
# Out:
# (20, 5)

# %%
#it tell info of dataset column wise with datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  20 non-null     int64
#  1   Name        20 non-null     object
#  2   Subject     20 non-null     object
#  3   Marks       20 non-null     int64
#  4   Attendance  20 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 928.0+ bytes

# %%
df.describe()
# Out:
#        Student_ID      Marks  Attendance
# count   20.000000  20.000000   20.000000
# mean   103.000000  61.050000   80.400000
# std      1.450953  21.067498   13.712845
# min    101.000000  30.000000   60.000000
# 25%    102.000000  40.750000   70.000000
# 50%    103.000000  63.500000   85.000000
# 75%    104.000000  78.750000   92.000000
# max    105.000000  92.000000   95.000000

# %%
#check for any empty cells
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Subject       0
# Marks         0
# Attendance    0
# dtype: int64

# %%
#checks any duplicate id
df.duplicated(subset=['Student_ID']).sum()
# Out:
# np.int64(15)

# %%
df['Result'] = df['Marks'].apply(lambda x: 'Pass' if x >= 40 else 'Fail')

# %%
result_count = df['Result'].value_counts()

# %%
plt.figure()
result_count.plot(kind='bar')
plt.title("Pass vs Fail Count")
plt.xlabel("Result")
plt.ylabel("Number of Students")
plt.show()

# %%
subject_avg = df.groupby('Subject')['Marks'].mean().sort_values(ascending=False)

# %%
plt.figure()
subject_avg.plot(kind='bar')
plt.title("Average Marks by Subject")
plt.xlabel("Subject")
plt.ylabel("Average Marks")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
plt.scatter(df['Attendance'], df['Marks'])
plt.title("Attendance vs Marks")
plt.xlabel("Attendance (%)")
plt.ylabel("Marks")
plt.show()

# %%
top_students = df.sort_values(by='Marks', ascending=False).head()
top_students
# Out:
#    Student_ID   Name         Subject  Marks  Attendance Result
# 13        104  Sneha         English     92          95   Pass
# 8         104  Sneha         Science     90          95   Pass
# 3         104  Sneha     Mathematics     88          95   Pass
# 18        104  Sneha  Social Studies     85          95   Pass
# 10        101  Aarav         English     81          92   Pass

# %%
low_students = df.sort_values(by='Marks').head()
low_students
# Out:
#    Student_ID   Name         Subject  Marks  Attendance Result
# 17        103  Rahul  Social Studies     30          60   Fail
# 2         103  Rahul     Mathematics     34          60   Fail
# 9         105  Kiran         Science     36          70   Fail
# 14        105  Kiran         English     39          70   Fail
# 7         103  Rahul         Science     40          60   Pass
